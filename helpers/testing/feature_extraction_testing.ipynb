# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sys.path.append("../")
from functions.feature_extraction import pca_feature_extraction, plot_pca_features, tsne_feature_extraction, plot_tsne_features, umap_feature_extraction

# %%
Fs = 30000
dt = 1/Fs
gain = .5  
PRIMARY_COLOUR = "black"

# %%
waveforms = np.load("../../tubingen_exersizes/data/nda_ex_1_waveforms.npy")
print(waveforms.shape)
# Out:
# (30, 20453, 4)

# %% [markdown]
# The shape corresponds to 20453 waveforms each with a window length of 30 across 4 recording channels

# %% [markdown]
# ## Principle Component Analysis (PCA)

# %%
waveforms.shape
# Out:
# (30, 20453, 4)

# %%
# choose number of principle components
n_components = 3

b, explained_variance_ratio = pca_feature_extraction(waveforms, n_components=n_components)

# %%
explained_variance_ratio
# Out:
# array([0.46982428, 0.21499557, 0.10573299])

# %%
b.shape
# Out:
# (20453, 12)

# %%
plot_pca_features(b, n_components=n_components)

# %% [markdown]
# ## t-Distributed Stochastic Neighbor Embedding (t-SNE)

# %%
n_components = 2
b = tsne_feature_extraction(waveforms)
# Out:
# /opt/anaconda3/envs/data_analytics/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/envs/data_analytics/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 n_components = 2
# ----> 2 b = tsne_feature_extraction(waveforms)
#
# File ~/DataProjects/dataScienceProject/helpers/testing/../functions/feature_extraction.py:141, in tsne_feature_extraction(waveforms, n_components)
#     139     # reshape to 2D array
#     140     waveforms_channel = waveforms_channel.reshape((num_spikes, -1))
# ...

# %%
plot_tsne_features(b)

# %% [markdown]
# ## Uniform Manifold Approximation and Projection (UMAP)

# %%
b = umap_feature_extraction(waveforms)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
b.shape
# Out:
# (20453, 8)

# %%
plot_tsne_features(b)
